# %%
import os
import sys
os.getcwd()
# Out:
# '/home/daniel/Documentos/Maestría/Proyecto_Tesis'

# %%
BASE_DIR = os.getcwd()   # carpeta del notebook
sys.path.append(BASE_DIR)

# %%
from drive_utils.auth import autenticar_drive

folder_ID = '14SZg0lMvcdkyiyvsdZ-WbR93HhIWRA1E'
service = autenticar_drive()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 from drive_utils.auth import autenticar_drive
#       3 folder_ID = '14SZg0lMvcdkyiyvsdZ-WbR93HhIWRA1E'
# ----> 4 service = autenticar_drive()
#
# File ~/Documentos/Maestría/Proyecto_Tesis/drive_utils/auth.py:20, in autenticar_drive()
#      18     creds.refresh(Request())
#      19 else:
# ---> 20     flow = InstalledAppFlow.from_client_secrets_file(
#      21         'credentials.json', SCOPES)
#      22     creds = flow.run_local_server(port=0)
#      24 with open('token.pickle', 'wb') as token:
#
# File ~/miniforge3/envs/dkist/lib/python3.14/site-packages/google_auth_oauthlib/flow.py:198, in Flow.from_client_secrets_file(cls, client_secrets_file, scopes, **kwargs)
#     183 @classmethod
#     184 def from_client_secrets_file(cls, client_secrets_file, scopes, **kwargs):
# ...
